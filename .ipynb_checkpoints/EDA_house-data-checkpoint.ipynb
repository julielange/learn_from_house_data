# %% [markdown]
# # Exploratory Data Analysis Project

# %% [markdown]
# ## Overview of the dataset and its variables

# %% [markdown]
# The underlying dataset describes the house market in King County/ WA. This dataset will be used for both providing advice to house buyers and sellers as well as for prediction purposes.

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np
# %matplotlib inline
pd.options.display.max_columns = None

# %%
df_var = pd.DataFrame({'Variables': ['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15'],
                    'Description': ['unique identified for a house', 'house was sold', 'is prediction target', 'of Bedrooms/House', 'of bathrooms/bedrooms', 'footage of the home', 'footage of the lot', 'floors (levels) in house', 'House which has a view to a waterfront', 'Has been viewed', 'How good the condition is ( Overall )', 'overall grade given to the housing unit, based on King County grading system', ' square footage of house apart from basement', 'square footage of the basement', 'Built Year', 'Year when house was renovated', 'zip', 'Latitude coordinate', 'Longitude coordinate', 'The square footage of interior housing living space for the nearest 15 neighbors', 'The square footage of the land lots of the nearest 15 neighbors']},
                     index=[i for i in range(21)])
df_var = df_var.style.set_properties(subset=['Description'], **{'width-min': '400px'})
df_var
# Out:
# <style  type="text/css" >
#     #T_9ae01942_aa8d_11ea_a31f_615373e81a36row0_col1 {
#             width-min:  400px;
#         }    #T_9ae01942_aa8d_11ea_a31f_615373e81a36row1_col1 {
#             width-min:  400px;
#         }    #T_9ae01942_aa8d_11ea_a31f_615373e81a36row2_col1 {
#             width-min:  400px;
#         }    #T_9ae01942_aa8d_11ea_a31f_615373e81a36row3_col1 {
#             width-min:  400px;
#         }    #T_9ae01942_aa8d_11ea_a31f_615373e81a36row4_col1 {
#             width-min:  400px;
#         }    #T_9ae01942_aa8d_11ea_a31f_615373e81a36row5_col1 {
#             width-min:  400px;
#         }    #T_9ae01942_aa8d_11ea_a31f_615373e81a36row6_col1 {
#             width-min:  400px;
#         }    #T_9ae01942_aa8d_11ea_a31f_615373e81a36row7_col1 {
#             width-min:  400px;
#         }    #T_9ae01942_aa8d_11ea_a31f_615373e81a36row8_col1 {
#             width-min:  400px;
#         }    #T_9ae01942_aa8d_11ea_a31f_615373e81a36row9_col1 {
#             width-min:  400px;
#         }    #T_9ae01942_aa8d_11ea_a31f_615373e81a36row10_col1 {
#             width-min:  400px;
#         }    #T_9ae01942_aa8d_11ea_a31f_615373e81a36row11_col1 {
#             width-min:  400px;
#         }    #T_9ae01942_aa8d_11ea_a31f_615373e81a36row12_col1 {
#             width-min:  400px;
#         }    #T_9ae01942_aa8d_11ea_a31f_615373e81a36row13_col1 {
#             width-min:  400px;
#         }    #T_9ae01942_aa8d_11ea_a31f_615373e81a36row14_col1 {
#             width-min:  400px;
#         }    #T_9ae01942_aa8d_11ea_a31f_615373e81a36row15_col1 {
#             width-min:  400px;
#         }    #T_9ae01942_aa8d_11ea_a31f_615373e81a36row16_col1 {
#             width-min:  400px;
#         }    #T_9ae01942_aa8d_11ea_a31f_615373e81a36row17_col1 {
#             width-min:  400px;
#         }    #T_9ae01942_aa8d_11ea_a31f_615373e81a36row18_col1 {
#             width-min:  400px;
#         }    #T_9ae01942_aa8d_11ea_a31f_615373e81a36row19_col1 {
#             width-min:  400px;
#         }    #T_9ae01942_aa8d_11ea_a31f_615373e81a36row20_col1 {
#             width-min:  400px;
#         }</style><table id="T_9ae01942_aa8d_11ea_a31f_615373e81a36" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Variables</th>        <th class="col_heading level0 col1" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9ae01942_aa8d_11ea_a31f_615373e81a36level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row0_col0" class="data row0 col0" >id</td>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row0_col1" class="data row0 col1" >unique identified for a house</td>
#             </tr>
#             <tr>
#                         <th id="T_9ae01942_aa8d_11ea_a31f_615373e81a36level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row1_col0" class="data row1 col0" >date</td>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row1_col1" class="data row1 col1" >house was sold</td>
#             </tr>
#             <tr>
#                         <th id="T_9ae01942_aa8d_11ea_a31f_615373e81a36level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row2_col0" class="data row2 col0" >price</td>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row2_col1" class="data row2 col1" >is prediction target</td>
#             </tr>
#             <tr>
#                         <th id="T_9ae01942_aa8d_11ea_a31f_615373e81a36level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row3_col0" class="data row3 col0" >bedrooms</td>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row3_col1" class="data row3 col1" >of Bedrooms/House</td>
#             </tr>
#             <tr>
#                         <th id="T_9ae01942_aa8d_11ea_a31f_615373e81a36level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row4_col0" class="data row4 col0" >bathrooms</td>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row4_col1" class="data row4 col1" >of bathrooms/bedrooms</td>
#             </tr>
#             <tr>
#                         <th id="T_9ae01942_aa8d_11ea_a31f_615373e81a36level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row5_col0" class="data row5 col0" >sqft_living</td>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row5_col1" class="data row5 col1" >footage of the home</td>
#             </tr>
#             <tr>
#                         <th id="T_9ae01942_aa8d_11ea_a31f_615373e81a36level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row6_col0" class="data row6 col0" >sqft_lot</td>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row6_col1" class="data row6 col1" >footage of the lot</td>
#             </tr>
#             <tr>
#                         <th id="T_9ae01942_aa8d_11ea_a31f_615373e81a36level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row7_col0" class="data row7 col0" >floors</td>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row7_col1" class="data row7 col1" >floors (levels) in house</td>
#             </tr>
#             <tr>
#                         <th id="T_9ae01942_aa8d_11ea_a31f_615373e81a36level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row8_col0" class="data row8 col0" >waterfront</td>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row8_col1" class="data row8 col1" >House which has a view to a waterfront</td>
#             </tr>
#             <tr>
#                         <th id="T_9ae01942_aa8d_11ea_a31f_615373e81a36level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row9_col0" class="data row9 col0" >view</td>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row9_col1" class="data row9 col1" >Has been viewed</td>
#             </tr>
#             <tr>
#                         <th id="T_9ae01942_aa8d_11ea_a31f_615373e81a36level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row10_col0" class="data row10 col0" >condition</td>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row10_col1" class="data row10 col1" >How good the condition is ( Overall )</td>
#             </tr>
#             <tr>
#                         <th id="T_9ae01942_aa8d_11ea_a31f_615373e81a36level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row11_col0" class="data row11 col0" >grade</td>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row11_col1" class="data row11 col1" >overall grade given to the housing unit, based on King County grading system</td>
#             </tr>
#             <tr>
#                         <th id="T_9ae01942_aa8d_11ea_a31f_615373e81a36level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row12_col0" class="data row12 col0" >sqft_above</td>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row12_col1" class="data row12 col1" > square footage of house apart from basement</td>
#             </tr>
#             <tr>
#                         <th id="T_9ae01942_aa8d_11ea_a31f_615373e81a36level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_9ae01942_aa8d_11ea_a31f_615373e81a36row13_col0" class="data row13 col0" >sqft_basement</td>

# %%
df = pd.read_csv('King_County_House_prices_dataset.csv')
df.head(10)
# Out:
#            id        date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014   221900.0         3       1.00         1180
# 1  6414100192   12/9/2014   538000.0         3       2.25         2570
# 2  5631500400   2/25/2015   180000.0         2       1.00          770
# 3  2487200875   12/9/2014   604000.0         4       3.00         1960
# 4  1954400510   2/18/2015   510000.0         3       2.00         1680
# 5  7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6  1321400060   6/27/2014   257500.0         3       2.25         1715
# 7  2008000270   1/15/2015   291850.0         3       1.50         1060
# 8  2414600126   4/15/2015   229500.0         3       1.00         1780
# 9  3793500160   3/12/2015   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0         NaN   0.0          3      7        1180
# 1      7242     2.0         0.0   0.0          3      7        2170
# 2     10000     1.0         0.0   0.0          3      6         770
# 3      5000     1.0         0.0   0.0          5      7        1050
# 4      8080     1.0         0.0   0.0          3      8        1680
# 5    101930     1.0         0.0   0.0          3     11        3890
# 6      6819     2.0         0.0   0.0          3      7        1715
# 7      9711     1.0         0.0   NaN          3      7        1060
# 8      7470     1.0         0.0   0.0          3      7        1050
# 9      6560     2.0         0.0   0.0          3      7        1890
#
#   sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0           0.0      1955           0.0    98178  47.5112 -122.257
# 1         400.0      1951        1991.0    98125  47.7210 -122.319
# 2           0.0      1933           NaN    98028  47.7379 -122.233
# 3         910.0      1965           0.0    98136  47.5208 -122.393
# 4           0.0      1987           0.0    98074  47.6168 -122.045
# 5        1530.0      2001           0.0    98053  47.6561 -122.005
# 6             ?      1995           0.0    98003  47.3097 -122.327
# 7           0.0      1963           0.0    98198  47.4095 -122.315
# 8         730.0      1960           0.0    98146  47.5123 -122.337
# 9           0.0      2003           0.0    98038  47.3684 -122.031
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503
# 5           4760      101930
# 6           2238        6819
# 7           1650        9711
# 8           1780        8113
# 9           2390        7570

# %%
df.shape
# Out:
# (21597, 21)

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront       float64
# view             float64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement     object
# yr_built           int64
# yr_renovated     float64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# Only sgft_basement is an object type variable, which should be changed to float or int. Also time related variables might be changed from numeric to datetime.

# %% [markdown]
# ## Non-Graphical Analysis

# %% [markdown]
# In order to prepare for graphical analysis and correlation calculations:
# * variables will be identified as numerical and categorical variables
# * datatypes will be changed if necessary
# * null values will treated

# %% [markdown]
# ### Statistical overview and unique values

# %%
df.describe().round(2)
# Out:
#                  id       price  bedrooms  bathrooms  sqft_living    sqft_lot  \
# count  2.159700e+04    21597.00  21597.00   21597.00     21597.00    21597.00
# mean   4.580474e+09   540296.57      3.37       2.12      2080.32    15099.41
# std    2.876736e+09   367368.14      0.93       0.77       918.11    41412.64
# min    1.000102e+06    78000.00      1.00       0.50       370.00      520.00
# 25%    2.123049e+09   322000.00      3.00       1.75      1430.00     5040.00
# 50%    3.904930e+09   450000.00      3.00       2.25      1910.00     7618.00
# 75%    7.308900e+09   645000.00      4.00       2.50      2550.00    10685.00
# max    9.900000e+09  7700000.00     33.00       8.00     13540.00  1651359.00
#
#          floors  waterfront      view  condition     grade  sqft_above  \
# count  21597.00    21597.00  21597.00   21597.00  21597.00    21597.00
# mean       1.49        0.01      0.23       3.41      7.66     1788.60
# std        0.54        0.08      0.76       0.65      1.17      827.76
# min        1.00        0.00      0.00       1.00      3.00      370.00
# 25%        1.00        0.00      0.00       3.00      7.00     1190.00
# 50%        1.50        0.00      0.00       3.00      7.00     1560.00
# 75%        2.00        0.00      0.00       4.00      8.00     2210.00
# max        3.50        1.00      4.00       5.00     13.00     9410.00
#
#        sqft_basement  yr_built  yr_renovated   zipcode       lat      long  \
# count       21597.00  21597.00      21597.00  21597.00  21597.00  21597.00
# mean          285.72   1971.00         68.76  98077.95     47.56   -122.21
# std           439.82     29.38        364.04     53.51      0.14      0.14
# min             0.00   1900.00          0.00  98001.00     47.16   -122.52
# 25%             0.00   1951.00          0.00  98033.00     47.47   -122.33
# 50%             0.00   1975.00          0.00  98065.00     47.57   -122.23
# 75%           550.00   1997.00          0.00  98118.00     47.68   -122.12
# max          4820.00   2015.00       2015.00  98199.00     47.78   -121.32
#
#        sqft_living15  sqft_lot15
# count       21597.00    21597.00
# mean         1986.62    12758.28
# std           685.23    27274.44
# min           399.00      651.00
# 25%          1490.00     5100.00
# 50%          1840.00     7620.00
# 75%          2360.00    10083.00
# max          6210.00   871200.00

# %%
df.nunique()
# Out:
# id               21420
# date               372
# price             3622
# bedrooms            12
# bathrooms           29
# sqft_living       1034
# sqft_lot          9776
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               11
# sqft_above         942
# sqft_basement      304
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5033
# long               751
# sqft_living15      777
# sqft_lot15        8682
# dtype: int64

# %% [markdown]
# Due to a low number of unique elements, categorical variables might be:
# * waterfront
# * view
# * condition
# * grade
# * floors

# %%
df.waterfront.unique()
# Out:
# array([nan,  0.,  1.])

# %% [markdown]
# Variable 'waterfront' needs to be cleaned from nan values.

# %% [markdown]
# ### Changing data types

# %%
df['date'] = pd.to_datetime(df['date'])
df['date'].head()
# Out:
# 0   NaT
# 1   NaT
# 2   NaT
# 3   NaT
# 4   NaT
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# ### Treating null values

# %%
df.isnull().sum()
# Out:
# id                   0
# date             21597
# price                0
# bedrooms             0
# bathrooms            0
# sqft_living          0
# sqft_lot             0
# floors               0
# waterfront           0
# view                 0
# condition            0
# grade                0
# sqft_above           0
# sqft_basement        0
# yr_built             0
# yr_renovated         0
# zipcode              0
# lat                  0
# long                 0
# sqft_living15        0
# sqft_lot15           0
# month_year           0
# rooms                0
# log_price            0
# geometry             0
# dtype: int64

# %% [markdown]
# missing values in: waterfront, view, yr_renovated

# %%
df['sqft_basement'] = pd.to_numeric(df.sqft_basement, errors='coerce').fillna(0)

# %%
df['sqft_basement'].value_counts().head()
# Out:
# 0.0      13280
# 600.0      217
# 500.0      209
# 700.0      208
# 800.0      201
# Name: sqft_basement, dtype: int64

# %%
df['yr_renovated'].value_counts().head()
# Out:
# 0.0       17011
# 2014.0       73
# 2003.0       31
# 2013.0       31
# 2007.0       30
# Name: yr_renovated, dtype: int64

# %%
df['yr_renovated'] = df['yr_renovated'].fillna(0)

# %%
df['yr_renovated'].value_counts().head()
# Out:
# 0.0       20853
# 2014.0       73
# 2003.0       31
# 2013.0       31
# 2007.0       30
# Name: yr_renovated, dtype: int64

# %% [markdown]
# nan, and 0 indicating missing values

# %%
df['view'].value_counts()
# Out:
# 0.0    19422
# 2.0      957
# 3.0      508
# 1.0      330
# 4.0      317
# Name: view, dtype: int64

# %%
df['view'] = df['view'].fillna(0)

# %%
df['waterfront'].value_counts()
# Out:
# 0.0    19075
# 1.0      146
# Name: waterfront, dtype: int64

# %%
df['waterfront'] = df['waterfront'].fillna(0)

# %% [markdown]
# ### Adding new features to the data set

# %%
df['rooms'] = df['bedrooms'] + df['bathrooms']*df['bedrooms']

# %%
df['rooms'].head()
# Out:
# 0     6.00
# 1     9.75
# 2     4.00
# 3    16.00
# 4     9.00
# Name: rooms, dtype: float64

# %% [markdown]
# ## Graphical Univariate Analysis
# * histogram to see if there is skewness and outliers (e.g. .hist() )
# * boxplots to get quartiles and outliers, max and min values (e.g. print(train.boxplot(column='disbursed_amount', by='Employment_state))
# * countplots used for categorical values (e.g. sns.countplot(train.loan_default)
# * https://towardsdatascience.com/reverse-geocoding-in-python-a915acf29eb6

# %% [markdown]
# ### Graphical Analysis of categorical variables

# %% [markdown]
# A histogram will be used to learn more about the distribution of following categorical variables:
# * waterfront
# * view
# * condition
# * grade
# * floors
# * rooms

# %%
import warnings
warnings.filterwarnings('ignore')
fig = plt.figure(figsize = (8,8))
ax = fig.gca()
df[['waterfront', 'view', 'condition', 'grade', 'floors', 'bedrooms', 'bathrooms', 'rooms']].hist(ax = ax);

# %% [markdown]
# ### Graphical Analysis of numeric variables

# %% [markdown]
# All other variables except for time related ones will be plotted against each other. This will help to understand relationships between each pair.

# %%
sns.pairplot(df[['id', 'date', 'price', 'sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement', 'bedrooms', 'bathrooms']]);

# %% [markdown]
# We will use a linear regression model later on for our house price predictions. A heatmap will help to identify those linear relationships. However, above pairplot would also show non-linear relationships, which are not relevant for our model but still good to know about when providing advice to seller or buyers.

# %%
corr = df.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(20, 16))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(
    corr,          # The data to plot
    mask=mask,     # Mask some cells
    cmap=cmap,     # What colors to plot the heatmap as
    annot=True,    # Should the values be plotted in the cells?
    vmax=.3,       # The maximum value of the legend. All higher vals will be same color
    vmin=-.3,      # The minimum value of the legend. All lower vals will be same color
    center=0,      # The center value of the legend. With divergent cmap, where white is
    square=True,   # Force cells to be square
    linewidths=.5, # Width of lines that divide cells
    cbar_kws={"shrink": .2}  # Extra kwargs for the legend; in this case, shrink by 50%
);

# %% [markdown]
# Accorindg to this heatmap price correlates with:
# * bedrooms
# * bathrooms
# * sqft_living
# * floors
# * waterfront
# * view
# * grade
# * sqft_above
# * sqft_basement
# * lat

# %%
sns.pairplot(df[['price', 'sqft_living', 'sqft_above', 'sqft_basement', 'bedrooms', 'bathrooms', 'floors', 'waterfront', 'view', 'grade', 'lat']]);

# %%
## Missing value treatment

# %%
## Outlier treatment

# %% [markdown]
# ## Correlation Analysis
# * data[[var1, var2, var3]].corr() or entire dataset identifying correlation coefficients
# * use sns.regplot(x = 'engine-size', y = 'price', data = data)      plt.ylim(0, ) to see scatterplot and regression line
# * visualize correlations with seaborn heatmap

# %% [markdown]
# ## OLS Analysis
# * do OLS for various combinations
# * find combination with R squared between 0.7 and 0.9

# %%
import statsmodels.formula.api as smf

smf.ols(formula='price' ~ 'sqft_living + sqft_above + sqft_basement + bedrooms + bathrooms + floors + waterfront + view + grade + lat', data=df).fit().summary()
# Out:
#   File "<ipython-input-49-234e4a37427e>", line 3
#     smf.ols(formula='price' ~ 'sqft_living + sqft_above + sqft_basement + bedrooms + bathrooms + floors + waterfront + view + grade + lat', data=df).fit().summary()
#                             ^
# SyntaxError: invalid syntax

# %%
import statsmodels.api as sm
X = df[['sqft_living', 'rooms', 'sqft_above', 'sqft_basement', 'bedrooms', 'bathrooms', 'floors', 'waterfront', 'view', 'grade', 'lat']]

X = sm.add_constant(X)
y = df.price

model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.666
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     3921.
# Date:                Tue, 09 Jun 2020   Prob (F-statistic):               0.00
# Time:                        22:52:37   Log-Likelihood:            -2.9553e+05
# No. Observations:               21597   AIC:                         5.911e+05
# Df Residuals:                   21585   BIC:                         5.912e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -3.123e+07   5.08e+05    -61.483      0.000   -3.22e+07   -3.02e+07
# sqft_living     150.0240     19.010      7.892      0.000     112.764     187.284
# rooms          3.991e+04   1647.846     24.221      0.000    3.67e+04    4.31e+04
# sqft_above       30.1903     18.972      1.591      0.112      -6.996      67.376
# sqft_basement    38.0185     18.874      2.014      0.044       1.023      75.013
# bedrooms      -1.478e+05   5398.027    -27.375      0.000   -1.58e+05   -1.37e+05
# bathrooms     -1.468e+05   6732.613    -21.808      0.000    -1.6e+05   -1.34e+05
# floors        -1.932e+04   3619.790     -5.337      0.000   -2.64e+04   -1.22e+04
# waterfront      6.35e+05   1.91e+04     33.267      0.000    5.98e+05    6.72e+05
# view           6.594e+04   2175.086     30.315      0.000    6.17e+04    7.02e+04
# grade          9.195e+04   2137.764     43.012      0.000    8.78e+04    9.61e+04
# lat            6.534e+05   1.07e+04     61.077      0.000    6.32e+05    6.74e+05
# ==============================================================================
# Omnibus:                    16435.848   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1075769.289
# Skew:                           3.104   Prob(JB):                         0.00
# Kurtosis:                      37.013   Cond. No.                     1.06e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.06e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X2 = df[['sqft_living', 'rooms', 'sqft_above', 'bathrooms', 'floors', 'grade', 'lat']]

X2 = sm.add_constant(X2)
y2 = df.price

model2 = sm.OLS(y2, X2)
results2 = model2.fit()
results2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.602
# Model:                            OLS   Adj. R-squared:                  0.602
# Method:                 Least Squares   F-statistic:                     4670.
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):               0.00
# Time:                        06:30:31   Log-Likelihood:            -2.9744e+05
# No. Observations:               21597   AIC:                         5.949e+05
# Df Residuals:                   21589   BIC:                         5.950e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -3.138e+07   5.51e+05    -56.915      0.000   -3.25e+07   -3.03e+07
# sqft_living   233.8646      4.724     49.508      0.000     224.606     243.124
# rooms       -5135.3537    659.118     -7.791      0.000   -6427.274   -3843.433
# sqft_above    -31.6323      4.664     -6.783      0.000     -40.773     -22.491
# bathrooms    2676.7989   4559.172      0.587      0.557   -6259.515    1.16e+04
# floors      -2.823e+04   3934.808     -7.175      0.000   -3.59e+04   -2.05e+04
# grade        9.485e+04   2310.612     41.048      0.000    9.03e+04    9.94e+04
# lat          6.489e+05   1.16e+04     55.775      0.000    6.26e+05    6.72e+05
# ==============================================================================
# Omnibus:                    19130.862   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1626023.162
# Skew:                           3.890   Prob(JB):                         0.00
# Kurtosis:                      44.790   Cond. No.                     1.05e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.05e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df.date.max()
# Out:
# Timestamp('2015-05-27 00:00:00')

# %%
df.date.min()
# Out:
# Timestamp('2014-05-02 00:00:00')

# %%
df.date.nunique()
# Out:
# 372

# %%
df.date.value_counts().head()
# Out:
# 2014-06-23    142
# 2014-06-25    131
# 2014-06-26    131
# 2014-07-08    127
# 2015-04-27    126
# Name: date, dtype: int64

# %%
df['month_year'] = df['date'].dt.to_period('M')
df['month_year'].head()
# Out:
# 0    2014-10
# 1    2014-12
# 2    2015-02
# 3    2014-12
# 4    2015-02
# Name: month_year, dtype: period[M]

# %%
df['month_year'] = df['month_year'].astype(str)
df['month_year'] = pd.to_datetime(df['month_year'])
df['month_year'].head()
# Out:
# 0   2014-10-01
# 1   2014-12-01
# 2   2015-02-01
# 3   2014-12-01
# 4   2015-02-01
# Name: month_year, dtype: datetime64[ns]

# %%
df['month_year'].min()
# Out:
# Timestamp('2014-05-01 00:00:00')

# %%
df[['month_year', 'price']].resample('M', on='month_year').mean().plot();

# %%
df['month_sold'] = df['date'].dt.to_period('Y')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-216-74b74e17538d> in <module>
# ----> 1 df['month_sold'] = df['date'].dt.to_period('Y')
#       2
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     169             # we're accessing the attribute of the class, i.e., Dataset.geo
#     170             return self._accessor
# --> 171         accessor_obj = self._accessor(obj)
#     172         # Replace the property with the accessor object. Inspired by:
#     173         # http://www.pydanny.com/cached-property.html
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/pandas/core/indexes/accessors.py in __new__(cls, data)
#     322             pass  # we raise an attribute error anyway
#     323
# --> 324         raise AttributeError("Can only use .dt accessor with datetimelike "
#     325                              "values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
df.head()
# Out:
#            id  date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520   NaN  221900.0         3       1.00         1180      5650
# 1  6414100192   NaN  538000.0         3       2.25         2570      7242
# 2  5631500400   NaN  180000.0         2       1.00          770     10000
# 3  2487200875   NaN  604000.0         4       3.00         1960      5000
# 4  1954400510   NaN  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0         0.0   0.0          3      7        1180            0.0
# 1     2.0         0.0   0.0          3      7        2170          400.0
# 2     1.0         0.0   0.0          3      6         770            0.0
# 3     1.0         0.0   0.0          5      7        1050          910.0
# 4     1.0         0.0   0.0          3      8        1680            0.0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955           0.0    98178  47.5112 -122.257           1340
# 1      1951        1991.0    98125  47.7210 -122.319           1690
# 2      1933           0.0    98028  47.7379 -122.233           2720
# 3      1965           0.0    98136  47.5208 -122.393           1360
# 4      1987           0.0    98074  47.6168 -122.045           1800
#
#    sqft_lot15 month_year
# 0        5650 2014-10-01
# 1        7639 2014-12-01
# 2        8062 2015-02-01
# 3        5000 2014-12-01
# 4        7503 2015-02-01

# %%
df['yr_built'] = df['yr_built'].astype(str)
df['yr_built'] = pd.to_datetime(df['yr_built'])

# %%
df[['yr_built', 'price']].resample('Y', on='yr_built').mean().plot();

# %%
df_renovated = df[['yr_renovated', 'price', 'grade']]
df_renovated = df_renovated[df_renovated.yr_renovated != 0]
df_renovated.head()
# Out:
#      yr_renovated      price  grade
# 1          1991.0   538000.0      7
# 35         2002.0   696000.0      8
# 95         1991.0   905000.0      7
# 103        2010.0  1090000.0      8
# 125        1992.0  1450000.0      8

# %%
df_renovated['yr_renovated'] = df_renovated['yr_renovated'].astype(float)
df_renovated['yr_renovated'] = df_renovated['yr_renovated'].astype(int)
df_renovated['yr_renovated'] = df_renovated['yr_renovated'].astype(str)

# %%
df_renovated['yr_renovated'] = pd.to_datetime(df_renovated['yr_renovated'])

df_renovated[['yr_renovated', 'grade']].resample('Y', on='yr_renovated').mean().plot();
# Out:
# 8.0

# %%
df.query('yr_renovated == 0').grade.median()
# Out:
# 7.0

# %%
df_renovated['grade'].median()
# Out:
# 8.0

# %% [markdown]
# Renovation leads to a higher grade median. As grade is positively related with price, it might be beneficial for sellers to do some investmens first before offering the property to potetial buyers.

# %%
df['month_year'].value_counts().plot()

# %%
df['condition'].hist()

# %%
df.condition.unique()
# Out:
# array([3, 5, 4, 1, 2])

# %%
df_waterfront = df[['waterfront', 'price']]
df_waterfront = df_waterfront[df.waterfront != 0]
df_waterfront.plot()
df_waterfront.price.median()
# Out:
# 1510000.0

# %%
df.price.median()
# Out:
# 450000.0

# %%
import math
df['log_price'] = [math.log(p) for p in df.price]

# %%
df_renovated.head()
# Out:
#     yr_renovated      price  grade
# 1     1991-01-01   538000.0      7
# 35    2002-01-01   696000.0      8
# 95    1991-01-01   905000.0      7
# 103   2010-01-01  1090000.0      8
# 125   1992-01-01  1450000.0      8

# %% [markdown]
# ## Prediction Model

# %% [markdown]
# The prediction model is based on linear regression and includes f ollowing variables:
# * sqft_living
# * sqft_above
# * bathrooms
# * floors
# * grade
# * lat
# * rooms

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
X = df[['sqft_living', 'sqft_above', 'bathrooms', 'floors', 'grade', 'lat', 'rooms']]
y = df['price']
y = np.log1p(y)

# %%
y.shape
# Out:
# (21597,)

# %%
X.shape
# Out:
# (21597, 7)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# -57.30776223841227
# [ 2.90470164e-04 -6.63721792e-05  1.80535718e-02  9.60032239e-03
#   1.59903181e-01  1.44337031e+00 -4.87498905e-03]

# %%
y_pred = regressor.predict(X_test)

# %%
df_model = pd.DataFrame({'Actual': np.exp(y_test), 'Predicted': np.exp(y_pred).round(2)})
df_model.head()
# Out:
#          Actual  Predicted
# 16729  244500.0  254572.55
# 10996  190000.0  276789.27
# 12089  348500.0  426853.51
# 554    396000.0  446831.75
# 16075  665000.0  565013.65

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.21578129931090057
# Mean Squared Error: 0.08061090395266893
# Root Mean Squared Error: 0.2839205944496963

# %% [markdown]
# ## Result
# Come up with at least 3 recommendations for house sellers and/or buyers in King County
